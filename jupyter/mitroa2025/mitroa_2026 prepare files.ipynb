# %%
import pandas as pd

# %%
df_eklektores2024 = pd.read_excel('../../files/mitroa/professors_tables/professors_export_20241211.xlsx', sheet_name='Professors')
df_eklektores2024.head()
# Out:
#    Κωδικός Χρήστη          Όνομα  Επώνυμο                            Φορέας  \
# 0            4200        IGNACIO       '-  University Complutense of Madrid
# 1            1869  ANDRE AARNINK  AARNINK                     Wageningen UR
# 2            5299           LEON   AARONS      The University of Manchester
# 3            4738         ERNEST   ABADAL           University of Barcelona
# 4           10536        GREGORY  ABADIAS                  Institut Pprime
#
#   Σχολή Τμήμα/Ινστιτούτο           Βαθμίδα              URL Βιογραφικού  \
# 0   NaN              NaN         Καθηγητής                          NaN
# 1   NaN              NaN  Κύριος Ερευνητής                          NaN
# 2   NaN              NaN         Καθηγητής                          NaN
# 3   NaN              NaN         Καθηγητής  http://bd.ub.edu/pub/abadal
# 4   NaN              NaN         Καθηγητής                          NaN
#
#                            Γνωστικό Αντικείμενο ΦΕΚ Διορισμού Σε αναστολή  \
# ...

# %%
df_eklektores2025 = pd.read_excel('../../files/mitroa/professors_tables/professors_export_20251014.xlsx', sheet_name='Professors')
df_eklektores2025.head()
# Out:
#    Κωδικός Χρήστη          Όνομα  Επώνυμο                            Φορέας  \
# 0            4200        IGNACIO       '-  University Complutense of Madrid
# 1            1869  ANDRE AARNINK  AARNINK                     Wageningen UR
# 2            5299           LEON   AARONS      The University of Manchester
# 3            4738         ERNEST   ABADAL           University of Barcelona
# 4           10536        GREGORY  ABADIAS                  Institut Pprime
#
#   Σχολή Τμήμα/Ινστιτούτο           Βαθμίδα              URL Βιογραφικού  \
# 0   NaN              NaN         Καθηγητής                          NaN
# 1   NaN              NaN  Κύριος Ερευνητής                          NaN
# 2   NaN              NaN         Καθηγητής                          NaN
# 3   NaN              NaN         Καθηγητής  http://bd.ub.edu/pub/abadal
# 4   NaN              NaN         Καθηγητής                          NaN
#
#                            Γνωστικό Αντικείμενο ΦΕΚ Διορισμού Σε αναστολή  \
# ...

# %%
df_eklektores2026 = pd.read_excel('../../files/mitroa/professors_tables/professors_export_20260904.xlsx', sheet_name='Professors')
df_eklektores2026.head()
# Out:
#    Κωδικός Χρήστη          Όνομα  Επώνυμο                            Φορέας  \
# 0            4200        IGNACIO       '-  University Complutense of Madrid
# 1            1869  ANDRE AARNINK  AARNINK                     Wageningen UR
# 2            5299           LEON   AARONS      The University of Manchester
# 3            4738         ERNEST   ABADAL           University of Barcelona
# 4           10536        GREGORY  ABADIAS                  Institut Pprime
#
#   Σχολή Τμήμα/Ινστιτούτο           Βαθμίδα              URL Βιογραφικού  \
# 0   NaN              NaN         Καθηγητής                          NaN
# 1   NaN              NaN  Κύριος Ερευνητής                          NaN
# 2   NaN              NaN         Καθηγητής                          NaN
# 3   NaN              NaN         Καθηγητής  http://bd.ub.edu/pub/abadal
# 4   NaN              NaN         Καθηγητής                          NaN
#
#                            Γνωστικό Αντικείμενο ΦΕΚ Διορισμού  \
# ...

# %%
df_eklektores2024.to_feather('../../files/mitroa/professors_tables/professors_export_20241211.feather')
df_eklektores2025.to_feather('../../files/mitroa/professors_tables/professors_export_20251014.feather')
df_eklektores2026.to_feather('../../files/mitroa/professors_tables/professors_export_20260904.feather')

# %%
df_eklektores2025.to_parquet('../../files/mitroa/professors_tables/professors_export_20251014.parquet')
df_eklektores2024.to_parquet('../../files/mitroa/professors_tables/professors_export_20241211.parquet')
df_eklektores2026.to_parquet('../../files/mitroa/professors_tables/professors_export_20260904.parquet')

# %%
df_test = pd.read_feather('../../files/mitroa/professors_tables/professors_export_20260904.feather')

# %%
df_test
# Out:
#        Κωδικός Χρήστη          Όνομα   Επώνυμο  \
# 0                4200        IGNACIO        '-
# 1                1869  ANDRE AARNINK   AARNINK
# 2                5299           LEON    AARONS
# 3                4738         ERNEST    ABADAL
# 4               10536        GREGORY   ABADIAS
# ...               ...            ...       ...
# 18891           19317        ΒΕΜΟΥΝΤ  ΩΡΜΠΑΚΚΕ
# 18892            9355       КОСТАДИН     ГАНЕВ
# 18893            3985         ГЕОРГИ   МАРИНОВ
# 18894            7275          СРЂАН  ПЕТРОВИЋ
# 18895            1568          БОРИС  СТРАУМАЛ
#
#                                                   Φορέας  \
# 0                       University Complutense of Madrid
# 1                                          Wageningen UR
# 2                           The University of Manchester
# 3                                University of Barcelona
# 4                                       Institut Pprime
# ...

# %%
df_test_parquet = pd.read_parquet('../../files/mitroa/professors_tables/professors_export_20260904.parquet')
df_test_parquet
# Out:
#        Κωδικός Χρήστη          Όνομα   Επώνυμο  \
# 0                4200        IGNACIO        '-
# 1                1869  ANDRE AARNINK   AARNINK
# 2                5299           LEON    AARONS
# 3                4738         ERNEST    ABADAL
# 4               10536        GREGORY   ABADIAS
# ...               ...            ...       ...
# 20281           19317        ΒΕΜΟΥΝΤ  ΩΡΜΠΑΚΚΕ
# 20282            9355       КОСТАДИН     ГАНЕВ
# 20283            3985         ГЕОРГИ   МАРИНОВ
# 20284            7275          СРЂАН  ПЕТРОВИЋ
# 20285            1568          БОРИС  СТРАУМАЛ
#
#                                                   Φορέας  \
# 0                       University Complutense of Madrid
# 1                                          Wageningen UR
# 2                           The University of Manchester
# 3                                University of Barcelona
# 4                                       Institut Pprime
# ...
