# %%
from docx2pdf import convert
from docxtpl import DocxTemplate
from docx2pdf import convert
import pandas as pd
# Out:
# d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\docxcompose\properties.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
template_file = r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\vasilas_files\Βεβαίωση παρακολούθησης Βασιλά template.docx"

# %%
df = pd.read_excel(r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\vasilas_files\Ομιλια_ΒΑΣΙΛΑ_attendance_list.xlsx") 
df
# Out:
#                                          name                           email  \
# 0                           Σαραφίδης Ιωάννης              johnsar3@gmail.com
# 1                            Μάμμος Δημήτριος       mamnosdimitris1@gmail.com
# 2                      Κουτσογιάννης Αντώνιος      koutsogiannispro@gmail.com
# 3                         Στεφανακίδη Ευγενία            stefjenny8@gmail.com
# 4                                 Σινέμ Σεφέρ         sinemsefer.04@gmail.com
# 5                        Σταυριανός Γρηγόριος            gregstavr0@gmail.com
# 6                               Χύσι Αγγελiνα         angelinachysi@gmail.com
# 7                         Παπαντωνίου Άγγελος        angelos.pap.gr@gmail.com
# 8                           Γρηγοριάδου Θωμαή    thomai.grigoriadou@gmail.com
# 9                           Χουδά Μπουτσακτσή          hboutsaktsi9@gmail.com
# 10                              Εντά Ιμπραχήμ        edaibrahim3377@gmail.com
# 11                           Στέλιος Βλαχάκης       steliosblaxakis@gmail.com
# 12                         Κυριακίδης Ανδρέας   andreas10kuriakidhs@gmail.com
# 13                           Γρηγόριος Κώστας                 grikosta@ihu.gr
# 14  Αγαπητόπουλος-Τσoντίλης Αλέξανδρος-Ραφαήλ        aagapitopoulos@gmail.com
# 15                    Ζουραράκης Κωνσταντίνος              konzoura@gmail.com
# 16                          Σουγλέρης Ιωάννης    giannissougleris12@gmail.com
# 17                         Αλέϊνα Γκιουλιστάν                 alegkiou@ihu.gr
# 18                         Γεωργιάδου Φωτεινή     fotinigeorgiadou9@gmail.com
# 19                            Ράπτης Ματθαίος        mattheosraptis@gmail.com
# 20                           Χατζής Αθανάσιος       hasoshatzis2005@gmail.com
# 21                           Πέτσιος Δημήτρης          jimmypetsios@gmail.com
# 22                 Πατέρας-Καραολάνης Βλάσιος            vlasiskapa@gmail.com
# 23                            Ντάντος Βασίλης         basilisntantos@yahoo.gr
# 24              Τσουντουράκη Φωτεινή-Ραφαηλία            tsfotinaki@gmail.com
# 25                             Γουγούση Σοφία        gougousisophia@gmail.com
# 26                      Νταφουλή Ειρήνη-Σοφία          eirinintaf14@gmail.com
# 27                             Ξυνού Λαμπρινή       lamprinhxynou@hotmail.com
# 28               Καρκάνης  Άγγελος Παρασκευάς             aggelisk4@gmail.com
# 29               Κοτζιάκαλφας Γεώργιος-Συμεών  kotziakalphasgiorgos@gmail.com
# 30                 Βασιλοκώστα Όλγα Παρασκευή    olga.s.vasilokwsta@gmail.com
# 31                              Θυμιατή Μαρία            tellmecafe@gmail.com
# 32                      Κουβαλακίδης Σπυρίδων                 spykouva@ihu.gr
#
#    article
# 0        Ο
# 1        Ο
# 2        Ο
# 3        Η
# 4        Η
# 5        Ο
# 6        Η
# 7        Ο
# 8        Η
# 9        Η
# 10       Η
# 11       Ο
# 12       Ο
# 13       Ο
# 14       Ο
# 15       Ο
# 16       Ο
# 17       Η
# 18       Η
# 19       Ο
# 20       Ο
# 21       Ο
# 22       Ο
# 23       Ο
# 24       Η
# 25       Η
# 26       Η
# 27       Η
# 28       Ο
# 29       Ο
# 30       Η
# 31       Η
# 32       Ο

# %%
def generate_certificate(row):
    doc = DocxTemplate(template_file)
    
    context = {
        'ΧΧΧΧΧΧΧΧΧΧΧ': row['name'],
        'article': row['article']
    }

    doc.render(context)
    output_docx = rf"output\Βεβαίωση_{row['name']}.docx"
    doc.save(output_docx)
    output_pdf = rf"output\Βεβαίωση_{row['name']}.pdf"
    convert(output_docx, output_pdf)


for index, row in df.iterrows():
    generate_certificate(row)
# Out:
# ---------------------------------------------------------------------------
# UndefinedError                            Traceback (most recent call last)
# Cell In[4], line 17
#      13     convert(output_docx, output_pdf)
#      16 for index, row in df.iterrows():
# ---> 17     generate_certificate(row)
#
# Cell In[4], line 9, in generate_certificate(row)
#       2 doc = DocxTemplate(template_file)
#       4 context = {
#       5     'ΧΧΧΧΧΧΧΧΧΧΧ': row['name'],
#       6     'ο-η': row['article']
#       7 }
# ----> 9 doc.render(context)
#      10 output_docx = rf"output\Βεβαίωση_{row['name']}.docx"
#      11 doc.save(output_docx)
#
# File d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\docxtpl\template.py:489, in DocxTemplate.render(self, context, jinja_env, autoescape)
#     486         jinja_env.autoescape = autoescape
#     488 # Body
# --> 489 xml_src = self.build_xml(context, jinja_env)
#     491 # fix tables if needed
#     492 tree = self.fix_tables(xml_src)
#
# File d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\docxtpl\template.py:436, in DocxTemplate.build_xml(self, context, jinja_env)
#     434 xml = self.get_xml()
#     435 xml = self.patch_xml(xml)
# --> 436 xml = self.render_xml_part(xml, self.docx._part, context, jinja_env)
#     437 return xml
#
# File d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\docxtpl\template.py:322, in DocxTemplate.render_xml_part(self, src_xml, part, context, jinja_env)
#     316         line_number = max(exc.lineno - 4, 0)
#     317         exc.docx_context = map(
#     318             lambda x: re.sub(r"<[^>]+>", "", x),
#     319             src_xml.splitlines()[line_number: (line_number + 7)],  # fmt: skip
#     320         )
# --> 322     raise exc
#     323 dst_xml = re.sub(r"\n<w:p([ >])", r"<w:p\1", dst_xml)
#     324 dst_xml = (
#     325     dst_xml.replace("{_{", "{{")
#     326     .replace("}_}", "}}")
#     327     .replace("{_%", "{%")
#     328     .replace("%_}", "%}")
#     329 )
#
# File d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\docxtpl\template.py:313, in DocxTemplate.render_xml_part(self, src_xml, part, context, jinja_env)
#     311     else:
#     312         template = Template(src_xml)
# --> 313     dst_xml = template.render(context)
#     314 except TemplateError as exc:
#     315     if hasattr(exc, "lineno") and exc.lineno is not None:
#
# File d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\jinja2\environment.py:1295, in Template.render(self, *args, **kwargs)
#    1293     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1294 except Exception:
# -> 1295     self.environment.handle_exception()
#
# File d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\jinja2\environment.py:942, in Environment.handle_exception(self, source)
#     937 """Exception handling helper.  This is used internally to either raise
#     938 rewritten exceptions or return a rendered traceback for the template.
#     939 """
#     940 from .debug import rewrite_traceback_stack
# --> 942 raise rewrite_traceback_stack(source=source)
#
# File <template>:7, in top-level template code()
#
# UndefinedError: 'ο' is undefined

# %%
# Load and modify the document
doc = DocxTemplate(template_file)

context = {
    'ΧΧΧΧΧΧΧΧΧΧΧ': 'YOUR_VALUE_HERE',
    'article': 'YOUR_VALUE'
}
doc.render(context)

# Save as DOCX first
output_docx = r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\Βεβαίωση παρακολούθησης Βασιλά - filled.docx"
doc.save(output_docx)

# Convert to PDF
output_pdf = r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\Βεβαίωση παρακολούθησης Βασιλά - filled.pdf"
convert(output_docx, output_pdf)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
