# %%
from docx2pdf import convert
from docxtpl import DocxTemplate
from docx2pdf import convert
import pandas as pd
# Out:
# d:\mypython_projects\civil_ihu_pyappz\.venv\Lib\site-packages\docxcompose\properties.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
template_file = r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\voutetaki_files\Βεβαίωση παρακολούθησης Βουτετάκη template.docx"

# %%
df = pd.read_excel(r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\voutetaki_files\Ομιλία Δρ. Βουτετάκη Εργαστήριο SEAL 10_03_2026.xlsx") 
df
# Out:
#                                name                            email article
# 0                   Ράπτης Ματθαίος         mattheosraptis@gmail.com       ο
# 1   Τσουντουράκη Φωτεινή - Ραφαηλία             tsfotinaki@gmail.com       η
# 2                  Χατζής Αθανάσιος        nasoshatzis2005@gmail.com       ο
# 3                   Πέτσος Δημήτρης           jimmypetsios@gmail.com       ο
# 4              Βασιλάκης Παναγιώτης           p13vasilakis@gmail.com       ο
# 5                Πασχαλίδου Κυριακή                  kyripash@ihu.gr       η
# 6              Ντομελασβίλι Γιώργος                  geontome@ihu.gr       ο
# 7           Λύτας Γεώργιος - Μάριος                  georlyta@ihu.gr       ο
# 8                    Δαντσάκη Μαρία          mariadantsaki@gmail.com       η
# 9                 Οικονόμου Γιώργος          giorgosoiko25@gmail.com       ο
# 10             Παπαδόπουλος Γιώργος       giorgospap322002@gmail.com       ο
# ...

# %%
def generate_certificate(row):
    doc = DocxTemplate(template_file)
    
    context = {
        'ΧΧΧΧΧΧΧΧΧΧΧ': row['name'],
        'article': row['article']
    }

    doc.render(context)
    output_docx = rf"output\Βεβαίωση_{row['name']}.docx"
    doc.save(output_docx)
    output_pdf = rf"output\Βεβαίωση_{row['name']}.pdf"
    convert(output_docx, output_pdf)


for index, row in df.iterrows():
    generate_certificate(row)
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Load and modify the document
doc = DocxTemplate(template_file)

context = {
    'ΧΧΧΧΧΧΧΧΧΧΧ': 'YOUR_VALUE_HERE',
    'article': 'YOUR_VALUE'
}
doc.render(context)

# Save as DOCX first
output_docx = r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\Βεβαίωση παρακολούθησης Βασιλά - filled.docx"
doc.save(output_docx)

# Convert to PDF
output_pdf = r"D:\mypython_projects\civil_ihu_pyappz\jupyter\vevaioseis\Βεβαίωση παρακολούθησης Βασιλά - filled.pdf"
convert(output_docx, output_pdf)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
